# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.cm as cm

# %%
font = {'family' : 'Times New Roman',
        'weight' : 'bold',
        'size'   : 10}

matplotlib.rc('font', **font)

# %%
data = pd.read_excel('num_of_neighbors.xlsx', sheet_name='Sheet2')


plt.figure(figsize=(10,10))

for n in [2, 4, 8, 16]:

    mask = (data['n'] == n)
    data_valid = data[mask]


    p = sns.boxplot(x = data_valid['k'], 
                y = data_valid['MSELoss'],
                color=cm.rainbow(n/16),
                showfliers = False,
                linewidth=1)
    # p.label(n)
    # plt.plot(label=n)

    # plt.title(f'n={n}')
# plt.legend()
plt.show()

# %%
data = pd.read_excel('num_of_neighbors.xlsx', sheet_name='Sheet2')

n = 4

mask = (data['n'] == n)
data_valid = data[mask]


plt.figure(figsize=(10,10))

sns.boxplot(x = data_valid['k'], 
            y = data_valid['MSELoss'],
            color='white')

plt.title(f'n={n}')
# Out:
# Text(0.5, 1.0, 'n=4')

# %%
data = pd.read_excel('num_of_neighbors.xlsx', sheet_name='Sheet2')

n = 8

mask = (data['n'] == n)
data_valid = data[mask]


plt.figure(figsize=(10,10))

sns.boxplot(x = data_valid['k'], 
            y = data_valid['MSELoss'],
            color='white')

plt.title(f'n={n}')
# Out:
# Text(0.5, 1.0, 'n=8')

# %%
data = pd.read_excel('num_of_neighbors.xlsx', sheet_name='Sheet2')

n = 16

mask = (data['n'] == n)
data_valid = data[mask]


plt.figure(figsize=(10,10))

sns.boxplot(x = data_valid['k'], 
            y = data_valid['MSELoss'],
            color='white')

plt.title(f'n={n}')
# Out:
# Text(0.5, 1.0, 'n=16')

# %%
data = pd.read_excel('num_of_neighbors.xlsx', sheet_name='Sheet2')

n = 2

mask = (data['n'] == n)
data_valid = data[mask]

plt.figure()

sns.boxplot(x = data_valid['k'], 
            y = data_valid['MSELoss'],
            color='white')

plt.title(f'n={n}')
# Out:
# Text(0.5, 1.0, 'n=2')

# %%
sns.boxplot(x = data['k'], 
            y = data['MSELoss'], 
            hue = data['n'],
            linewidth=0,
            showfliers = True)
# Out:
# <AxesSubplot:xlabel='k', ylabel='MSELoss'>

# %%
plt.figure(figsize=(20,20))
sns.boxplot(x = data['k'], 
            y = data['MSELoss'], 
            hue = data['n'],
            linewidth=0.5,
            showfliers = False)
# Out:
# <AxesSubplot:xlabel='k', ylabel='MSELoss'>

# %%
sns.boxplot(x = data['k'], 
            y = data['MSELoss'], 
            hue = data['n'],
            linewidth=0,
            showfliers = False)
# Out:
# <AxesSubplot:xlabel='k', ylabel='MSELoss'>

# %%
mask = (data['n'] != 2)
data_valid = data[mask]

sns.boxplot(x = data_valid['k'], 
            y = data_valid['MSELoss'], 
            hue = data_valid['n'],
            linewidth=0,
            showfliers = True)
# Out:
# <AxesSubplot:xlabel='k', ylabel='MSELoss'>

# %%
mask = (data['n'] != 2)
data_valid = data[mask]

plt.figure(figsize=(10,10))
sns.boxplot(x = data_valid['k'], 
            y = data_valid['MSELoss'], 
            hue = data_valid['n'],
            linewidth=0.5,
            showfliers = False)
# Out:
# <AxesSubplot:xlabel='k', ylabel='MSELoss'>

# %%
mask = (data['n'] != 2)
data_valid = data[mask]

sns.boxplot(x = data_valid['k'], 
            y = data_valid['MSELoss'], 
            hue = data_valid['n'],
            linewidth=0,
            showfliers = False)
# Out:
# <AxesSubplot:xlabel='k', ylabel='MSELoss'>
